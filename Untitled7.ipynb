# %% [markdown]
# <a href="https://colab.research.google.com/github/GabrielMartins-FM/Exercicio-Git/blob/main/Untitled7.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %% [markdown]
# Exercicio 1

# %%
a = int(input("Digite um número: "))
b = int(input("Digite outro número: "))

soma = a + b

print("Resultado:", soma)
# Out:
# Digite um número: 2
# Digite outro número: 4
# Resultado: 6

# %% [markdown]
# Exercicio 2

# %%
n1 = float(input("Digite o primeiro número: "))
n2 = float(input("Digite o segundo número: "))
n3 = float(input("Digite o terceiro número: "))

media = (n1 + n2 + n3) / 3

print("Média:", media)
# Out:
# Digite o primeiro número: 8
# Digite o segundo número: 6
# Digite o terceiro número: 4
# Média: 6.0

# %% [markdown]
# Exercicio 3

# %%
largura = float(input("Digite a largura: "))
altura = float(input("Digite a altura: "))

area = largura * altura

print("Área:", area)
# Out:
# Digite a largura: 30
# Digite a altura: 3
# Área: 90.0

# %% [markdown]
# Exercicio 4

# %%
reais = float(input("Digite o valor em reais: "))

dolares = reais / 6

print("Em dólares:", dolares)
# Out:
# Digite o valor em reais: 1000
# Em dólares: 166.66666666666666

# %% [markdown]
# Exercicio 5

# %%
c = float(input("Digite a temperatura em Celsius: "))

f = ((c * 9) / 5) + 32

print("Em Fahrenheit:", f)
# Out:
# Digite a temperatura em Celsius: 26
# Em Fahrenheit: 78.8

# %% [markdown]
# Exercicio 6

# %%
largura = float(input("Digite a largura da parede: "))
altura = float(input("Digite a altura da parede: "))

area = largura * altura
tinta = area / 2

print("Área:", area)
print("Litros de tinta:", tinta)
# Out:
# Digite a largura da parede: 3
# Digite a altura da parede: 5
# Área: 15.0
# Litros de tinta: 7.5

# %% [markdown]
# Exercicio 7

# %%
a = float(input("Digite A: "))
b = float(input("Digite B: "))
c = float(input("Digite C: "))

delta = (b * b) - (4 * a * c)

print("Delta:", delta)
# Out:
# Digite A: 7
# Digite B: 9
# Digite C: 3
# Delta: -3.0

# %% [markdown]
# Exercicio 8

# %%
preco = float(input("Digite o preço: "))

novo_preco = preco - (preco * 0.05)

print("Preço com desconto:", novo_preco)
# Out:
# Digite o preço: 150
# Preço com desconto: 142.5

# %% [markdown]
# Exercicio 9

# %%
salario = float(input("Digite o salário: "))

novo_salario = salario + (salario * 0.15)

print("Novo salário:", novo_salario)
# Out:
# Digite o salário: 1560
# Novo salário: 1794.0

# %% [markdown]
# Exercicio 10

# %%
km = float(input("Quantos km rodados: "))
dias = int(input("Quantos dias alugado: "))

total = (dias * 90) + (km * 0.20)

print("Total a pagar:", total)
# Out:
# Quantos km rodados: 133
# Quantos dias alugado: 5
# Total a pagar: 476.6

# %% [markdown]
# Exercicio 11

# %%
dias = int(input("Dias trabalhados: "))

horas = dias * 6
salario = horas * 45

print("Salário:", salario)
# Out:
# Dias trabalhados: 7
# Salário: 1890

# %% [markdown]
# Exercicio 12 Desafio

# %%
cigarros_dia = int(input("Cigarros por dia: "))
anos_fumando = int(input("Anos fumando: "))

dias_perdidos = (cigarros_dia * anos_fumando * 365 * 10) / 1440

print("Dias de vida perdidos:", dias_perdidos)
# Out:
# Cigarros por dia: 15
# Anos fumando: 20
# Dias de vida perdidos: 760.4166666666666
